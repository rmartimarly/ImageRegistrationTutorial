# %% [markdown]
# # Tutorial on Intensity Based registration
#
# Robert Martí robert.marti@udg.edu
# University of Girona

# %% [markdown]
# A radiologist comes to your office and asks to help him for a very complicated problem: he has two images of the same patient and wants to find the changes the had happened in the two image: lesions, etc.
#
# ![brain1.png](attachment:brain1.png) ![brain2%20-%20lesion.png](attachment:brain2%20-%20lesion.png)

# %% [markdown]
# Could we measure how similar are two images?

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import cv2

# %%
# Load both images
img_reference = cv2.imread('messi5.jpg',0)
img_target= cv2.imread('messi5.jpg',0)
