# %% [markdown]
# # Tutorial on Intensity Based registration
#
# Robert Martí robert.marti@udg.edu
# University of Girona

# %% [markdown]
# The idea of image registration is to align images of the same region/object. In other words, try to transform on image (the target image) in order to match the reference image.
#
# ![image_reg.png](attachment:image_reg.png)
